# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaurav-Ramachandra/AI-Lab/blob/main/AI_Lab5_29_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import math
import time

def calculate_conflicts(board):
    # Count the number of conflicts on the board
    n = len(board)
    conflicts = 0
    for i in range(n):
        for j in range(i + 1, n):
            if board[i] == board[j] or abs(board[i] - board[j]) == abs(i - j):
                conflicts += 1
    return conflicts

def display_board(board):
    if board:
        n = len(board)
        for i in range(n):
            row = ['Q' if board[i] == j else '.' for j in range(n)]
            print(" ".join(row))
        print("\n")
    else:
        print("No solution found.")

def simulated_annealing(board, initial_temp=100, cooling_rate=0.99, min_temp=0.1):
    current_board = board[:]
    current_conflicts = calculate_conflicts(current_board)
    temperature = initial_temp

    print("Initial Board with Conflicts:", current_conflicts)
    display_board(current_board)

    while temperature > min_temp and current_conflicts > 0:
        # Generate a new candidate board by moving a random queen
        new_board = current_board[:]
        row = random.randint(0, len(board) - 1)
        new_board[row] = random.randint(0, len(board) - 1)
        new_conflicts = calculate_conflicts(new_board)

        # Calculate probability of accepting new board
        delta = new_conflicts - current_conflicts
        if delta < 0 or random.uniform(0, 1) < math.exp(-delta / temperature):
            current_board = new_board
            current_conflicts = new_conflicts
            print(f"Temperature: {temperature:.2f}, Conflicts: {current_conflicts}")
            display_board(current_board)
            time.sleep(0.5)  # Pause to show step-by-step progress

        # Cool down
        temperature *= cooling_rate

    # Check if solution was found
    if current_conflicts == 0:
        print("Solution Found:")
        display_board(current_board)
        return current_board
    else:
        print("No solution found.")
        return None

if __name__ == "__main__":
    n = int(input("Enter the value of N for the N-Queens problem: "))
    board = []

    print("Enter the initial positions of queens (column number for each row):")
    for i in range(n):
        col = int(input(f"Row {i + 1}: ")) - 1  # Adjust to 0-based indexing for internal storage
        board.append(col)

    solution = simulated_annealing(board)
# Out:
# Enter the value of N for the N-Queens problem: 4
# Enter the initial positions of queens (column number for each row):
# Row 1: 2
# Row 2: 1
# Row 3: 4
# Row 4: 3
# Initial Board with Conflicts: 4
# . Q . .
# Q . . .
# . . . Q
# . . Q .
#
#
# Temperature: 100.00, Conflicts: 4
# . Q . .
# Q . . .
# . . . Q
# . . Q .
#
#
# Temperature: 99.00, Conflicts: 4
# . Q . .
# Q . . .
# . . . Q
# . . Q .
#
#
# Temperature: 98.01, Conflicts: 5
# . Q . .
# . . Q .
# . . . Q
# . . Q .
#
#
# Temperature: 97.03, Conflicts: 5
# . Q . .
# . . Q .
# . . . Q
# . . Q .
#
#
# Temperature: 96.06, Conflicts: 2
# . Q . .
# . . Q .
# Q . . .
# . . Q .
#
#
# Temperature: 95.10, Conflicts: 3
# . Q . .
# . . Q .
# Q . . .
# . Q . .
#
#
# Temperature: 94.15, Conflicts: 4
# . Q . .
# Q . . .
# Q . . .
# . Q . .
#
#
# Temperature: 93.21, Conflicts: 3
# . Q . .
# . . . Q
# Q . . .
# . Q . .
#
#
# Temperature: 92.27, Conflicts: 3
# Q . . .
# . . . Q
# Q . . .
# . Q . .
#
#
# Temperature: 91.35, Conflicts: 2
# Q . . .
# . . . Q
# . Q . .
# . Q . .
#
#
# Temperature: 90.44, Conflicts: 2
# Q . . .
# . . . Q
# . . . Q
# . Q . .
#
#
# Temperature: 89.53, Conflicts: 4
# Q . . .
# . . . Q
# . . . Q
# . . . Q
#
#
# Temperature: 88.64, Conflicts: 2
# Q . . .
# . . . Q
# . . . Q
# Q . . .
#
#
# Temperature: 87.75, Conflicts: 2
# Q . . .
# . . . Q
# . . . Q
# . Q . .
#
#
# Temperature: 86.87, Conflicts: 2
# Q . . .
# . Q . .
# . . . Q
# . Q . .
#
#
# Temperature: 86.01, Conflicts: 2
# . . . Q
# . Q . .
# . . . Q
# . Q . .
#
#
# Temperature: 85.15, Conflicts: 4
# . . . Q
# . Q . .
# . . . Q
# . . . Q
#
#
# Temperature: 84.29, Conflicts: 4
# . . . Q
# . Q . .
# . . . Q
# . . . Q
#
#
# Temperature: 83.45, Conflicts: 5
# . . . Q
# . . Q .
# . . . Q
# . . . Q
#
#
# Temperature: 82.62, Conflicts: 4
# . . . Q
# . . Q .
# . . Q .
# . . . Q
#
#
# Temperature: 81.79, Conflicts: 3
# . . . Q
# . . Q .
# . . Q .
# . Q . .
#
#
# Temperature: 80.97, Conflicts: 4
# . . . Q
# . . Q .
# . . Q .
# . . . Q
#
#
# Temperature: 80.16, Conflicts: 4
# . . . Q
# . Q . .
# . . Q .
# . . . Q
#
#
# Temperature: 79.36, Conflicts: 3
# . . . Q
# . Q . .
# Q . . .
# . . . Q
#
#
# Temperature: 78.57, Conflicts: 5
# Q . . .
# . Q . .
# Q . . .
# . . . Q
#
#
# Temperature: 77.78, Conflicts: 4
# Q . . .
# . Q . .
# . Q . .
# . . . Q
#
#
# Temperature: 77.00, Conflicts: 4
# Q . . .
# . Q . .
# . Q . .
# . . . Q
#
#
# Temperature: 76.23, Conflicts: 4
# Q . . .
# . Q . .
# . . . Q
# . . . Q
#
#
# Temperature: 75.47, Conflicts: 4
# Q . . .
# . Q . .
# . . . Q
# . . . Q
#
#
# Temperature: 74.72, Conflicts: 4
# . Q . .
# . Q . .
# . . . Q
# . . . Q
#
#
# Temperature: 73.97, Conflicts: 4
# . Q . .
# . . . Q
# . . . Q
# . . . Q
#
#
# Temperature: 73.23, Conflicts: 4
# . Q . .
# . Q . .
# . . . Q
# . . . Q
#
#
# Temperature: 72.50, Conflicts: 4
# . Q . .
# . Q . .
# . . . Q
# . . . Q
#
#
# Temperature: 71.77, Conflicts: 4
# . Q . .
# . Q . .
# . . Q .
# . . . Q
#
#
# Temperature: 71.06, Conflicts: 4
# . . . Q
# . Q . .
# . . Q .
# . . . Q
#
#
# Temperature: 70.34, Conflicts: 3
# . . . Q
# . Q . .
# . . Q .
# . Q . .
#
#
# Temperature: 69.64, Conflicts: 3
# . . . Q
# . Q . .
# . . Q .
# . Q . .
#
#
# Temperature: 68.94, Conflicts: 3
# . . . Q
# . Q . .
# Q . . .
# . Q . .
#
#
# Temperature: 68.26, Conflicts: 2
# . . . Q
# . . Q .
# Q . . .
# . Q . .
#
#
# Temperature: 67.57, Conflicts: 4
# . . . Q
# . . Q .
# Q . . .
# Q . . .
#
#
# Temperature: 66.90, Conflicts: 4
# . . . Q
# . . Q .
# Q . . .
# Q . . .
#
#
# Temperature: 66.23, Conflicts: 4
# . . . Q
# . . Q .
# . . Q .
# Q . . .
#
#
# Temperature: 65.57, Conflicts: 3
# . . . Q
# . . . Q
# . . Q .
# Q . . .
#
#
# Temperature: 64.91, Conflicts: 3
# . . . Q
# . . . Q
# . . Q .
# Q . . .
#
#
# Temperature: 64.26, Conflicts: 4
# . . . Q
# . . Q .
# . . Q .
# Q . . .
#
#
# Temperature: 63.62, Conflicts: 3
# . Q . .
# . . Q .
# . . Q .
# Q . . .
#
#
# Temperature: 62.98, Conflicts: 4
# . . Q .
# . . Q .
# . . Q .
# Q . . .
#
#
# Temperature: 62.35, Conflicts: 3
# . . Q .
# . . . Q
# . . Q .
# Q . . .
#
#
# Temperature: 61.73, Conflicts: 5
# . . Q .
# . . . Q
# . . Q .
# . Q . .
#
#
# Temperature: 61.11, Conflicts: 5
# . . Q .
# . . . Q
# . . Q .
# . . . Q
#
#
# Temperature: 60.50, Conflicts: 5
# Q . . .
# . . . Q
# . . Q .
# . . . Q
#
#
# Temperature: 59.90, Conflicts: 2
# Q . . .
# . . . Q
# . Q . .
# . . . Q
#
#
# Temperature: 59.30, Conflicts: 2
# . . Q .
# . . . Q
# . Q . .
# . . . Q
#
#
# Temperature: 58.70, Conflicts: 5
# . . Q .
# . . . Q
# . . Q .
# . . . Q
#
#
# Temperature: 58.12, Conflicts: 4
# . . Q .
# . . . Q
# . . . Q
# . . . Q
#
#
# Temperature: 57.54, Conflicts: 4
# Q . . .
# . . . Q
# . . . Q
# . . . Q
#
#
# Temperature: 56.96, Conflicts: 2
# Q . . .
# . . . Q
# . . . Q
# . . Q .
#
#
# Temperature: 56.39, Conflicts: 2
# Q . . .
# . . . Q
# . . . Q
# . . Q .
#
#
# Temperature: 55.83, Conflicts: 2
# Q . . .
# . . . Q
# . . . Q
# . . Q .
#
#
# Temperature: 55.27, Conflicts: 2
# Q . . .
# . . . Q
# . . . Q
# . . Q .
#
#
# Temperature: 54.72, Conflicts: 4
# . . Q .
# . . . Q
# . . . Q
# . . Q .
#
#
# Temperature: 54.17, Conflicts: 4
# . . Q .
# . . . Q
# . . . Q
# . . . Q
#
#
# Temperature: 53.63, Conflicts: 4
# . . Q .
# . . . Q
# . . . Q
# . . . Q
#
#
# Temperature: 53.09, Conflicts: 4
# . . Q .
# . . . Q
# . . . Q
# . . . Q
#
#
# Temperature: 52.56, Conflicts: 4
# . . Q .
# . . . Q
# . . . Q
# . . . Q
#
#
# Temperature: 52.03, Conflicts: 1
# . . Q .
# Q . . .
# . . . Q
# . . . Q
#
#
# Temperature: 51.51, Conflicts: 3
# . Q . .
# Q . . .
# . . . Q
# . . . Q
#
#
# Temperature: 51.00, Conflicts: 3
# Q . . .
# Q . . .
# . . . Q
# . . . Q
#
#
# Temperature: 50.49, Conflicts: 3
# Q . . .
# Q . . .
# . . . Q
# . . . Q
#
#
# Temperature: 49.98, Conflicts: 4
# Q . . .
# Q . . .
# Q . . .
# . . . Q
#
#
# Temperature: 49.48, Conflicts: 4
# Q . . .
# Q . . .
# Q . . .
# . Q . .
#
#
# Temperature: 48.99, Conflicts: 6
# Q . . .
# Q . . .
# Q . . .
# Q . . .
#
#
# Temperature: 48.50, Conflicts: 6
# Q . . .
# Q . . .
# Q . . .
# Q . . .
#
#
# Temperature: 48.01, Conflicts: 5
# Q . . .
# . Q . .
# Q . . .
# Q . . .
#
#
# Temperature: 47.53, Conflicts: 4
# Q . . .
# . Q . .
# . Q . .
# Q . . .
#
#
# Temperature: 47.06, Conflicts: 2
# Q . . .
# . . . Q
# . Q . .
# Q . . .
#
#
# Temperature: 46.59, Conflicts: 2
# Q . . .
# . . . Q
# . Q . .
# Q . . .
#
#
# Temperature: 46.12, Conflicts: 2
# . Q . .
# . . . Q
# . Q . .
# Q . . .
#
#
# Temperature: 45.66, Conflicts: 4
# . Q . .
# . . . Q
# . Q . .
# . Q . .
#
#
# Temperature: 45.20, Conflicts: 2
# . Q . .
# . . . Q
# . Q . .
# Q . . .
#
#
# Temperature: 44.75, Conflicts: 2
# . Q . .
# . . . Q
# . Q . .
# Q . . .
#
#
# Temperature: 43.86, Conflicts: 2
# . Q . .
# . . . Q
# . Q . .
# . . . Q
#
#
# Temperature: 43.42, Conflicts: 2
# . . Q .
# . . . Q
# . Q . .
# . . . Q
#
#
# Temperature: 42.99, Conflicts: 2
# . Q . .
# . . . Q
# . Q . .
# . . . Q
#
#
# Temperature: 42.56, Conflicts: 2
# . Q . .
# . . . Q
# . Q . .
# . . . Q
#
#
# Temperature: 42.13, Conflicts: 2
# . . Q .
# . . . Q
# . Q . .
# . . . Q
#
#
# Temperature: 41.71, Conflicts: 2
# . . Q .
# . . . Q
# . Q . .
# . . . Q
#
#
# Temperature: 41.29, Conflicts: 3
# . . Q .
# . . . Q
# . Q . .
# . . Q .
#
#
# Temperature: 40.88, Conflicts: 3
# . . Q .
# . . . Q
# . Q . .
# . . Q .
#
#
# Temperature: 40.47, Conflicts: 5
# . . Q .
# . . . Q
# . . Q .
# . . Q .
#
#
# Temperature: 40.07, Conflicts: 5
# . . Q .
# . . . Q
# . . Q .
# . . Q .
#
#
# Temperature: 39.67, Conflicts: 5
# . . Q .
# . . . Q
# . . Q .
# . Q . .
#
#
# Temperature: 39.27, Conflicts: 5
# . . Q .
# . . . Q
# . . Q .
# . Q . .
#
#
# Temperature: 38.88, Conflicts: 3
# . . Q .
# . . . Q
# . Q . .
# . Q . .
#
#
# Temperature: 38.49, Conflicts: 2
# . . Q .
# . . . Q
# . Q . .
# . . . Q
#
#
# Temperature: 38.10, Conflicts: 2
# . . Q .
# . . . Q
# . Q . .
# . . . Q
#
#
# Temperature: 37.72, Conflicts: 3
# . . Q .
# . Q . .
# . Q . .
# . . . Q
#
#
# Temperature: 37.35, Conflicts: 2
# . . Q .
# . . Q .
# . Q . .
# . . . Q
#
#
# Temperature: 36.97, Conflicts: 2
# . . Q .
# . . Q .
# . Q . .
# . . . Q
#
#
# Temperature: 36.60, Conflicts: 4
# . . . Q
# . . Q .
# . Q . .
# . . . Q
#
#
# Temperature: 36.24, Conflicts: 2
# . . . Q
# . . Q .
# Q . . .
# . . . Q
#
#
# Temperature: 35.87, Conflicts: 2
# . . . Q
# . . Q .
# Q . . .
# . . . Q
#
#
# Temperature: 35.52, Conflicts: 2
# . . . Q
# . . Q .
# Q . . .
# . Q . .
#
#
# Temperature: 35.16, Conflicts: 2
# . . . Q
# . . Q .
# Q . . .
# . Q . .
#
#
# Temperature: 34.81, Conflicts: 2
# . . . Q
# . . Q .
# Q . . .
# . . Q .
#
#
# Temperature: 34.46, Conflicts: 2
# . . . Q
# . . Q .
# Q . . .
# . . Q .
#
#
# Temperature: 34.12, Conflicts: 5
# . . . Q
# . . Q .
# . . . Q
# . . Q .
#
#
# Temperature: 33.78, Conflicts: 5
# . . . Q
# . . Q .
# . . . Q
# . . . Q
#
#
# Temperature: 33.44, Conflicts: 5
# . . . Q
# . . Q .
# . . . Q
# . . . Q
#
#
# Temperature: 33.10, Conflicts: 5
# . . . Q
# . . Q .
# . . . Q
# . . . Q
#
#
# Temperature: 32.77, Conflicts: 6
# . . . Q
# . . . Q
# . . . Q
# . . . Q
#
#
# Temperature: 32.44, Conflicts: 6
# . . . Q
# . . . Q
# . . . Q
# . . . Q
#
#
# Temperature: 32.12, Conflicts: 4
# . . . Q
# . Q . .
# . . . Q
# . . . Q
#
#
# Temperature: 31.80, Conflicts: 2
# . . . Q
# . Q . .
# . . . Q
# Q . . .
#
#
# Temperature: 31.48, Conflicts: 2
# . . . Q
# . Q . .
# . . . Q
# Q . . .
#
#
# Temperature: 31.17, Conflicts: 2
# . . . Q
# . Q . .
# . . . Q
# Q . . .
#
#
# Temperature: 30.85, Conflicts: 3
# . . . Q
# Q . . .
# . . . Q
# Q . . .
#
#
# Temperature: 30.55, Conflicts: 3
# . . . Q
# Q . . .
# . . . Q
# . . Q .
#
#
# Temperature: 30.24, Conflicts: 3
# . . . Q
# Q . . .
# . . . Q
# . . Q .
#
#
# Temperature: 29.94, Conflicts: 3
# . . Q .
# Q . . .
# . . . Q
# . . Q .
#
#
# Temperature: 29.64, Conflicts: 0
# . . Q .
# Q . . .
# . . . Q
# . Q . .
#
#
# Solution Found:
# . . Q .
# Q . . .
# . . . Q
# . Q . .
